# %% [markdown]
# ### Data Paths

# %%
train_data_path = 'data/train.csv'
test_data_path = 'data/test.csv'

# %% [markdown]
# ### Importing the Data

# %%
import pandas as pd
train_df = pd.read_csv(train_data_path)
test_df = pd.read_csv(test_data_path)
train_df.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.923527         -0.934724  ...                        -0.710304
# 1         -0.957686         -0.943068  ...                        -0.861499
# 2         -0.977469         -0.938692  ...                        -0.760104
# 3         -0.989302         -0.938692  ...                        -0.482845
# 4         -0.990441         -0.942469  ...                        -0.699205
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.112754                              0.030400
# 1                     0.053477                             -0.007435
# 2                    -0.118559                              0.177899
# 3                    -0.036788                             -0.012892
# 4                     0.123320                              0.122542
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.464761                             -0.018446
# 1                         -0.732626                              0.703511
# 2                          0.100699                              0.808529
# 3                          0.640011                             -0.485366
# 4                          0.693578                             -0.615971
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.841247              0.179941             -0.058627        1
# 1             -0.844788              0.180289             -0.054317        1
# 2             -0.848933              0.180637             -0.049118        1
# 3             -0.848649              0.181935             -0.047663        1
# 4             -0.847865              0.185151             -0.043892        1
#
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING
#
# [5 rows x 563 columns]

# %%
train_df.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        7352.000000        7352.000000        7352.000000
# mean            0.274488          -0.017695          -0.109141
# std             0.070261           0.040811           0.056635
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262975          -0.024863          -0.120993
# 50%             0.277193          -0.017219          -0.108676
# 75%             0.288461          -0.010783          -0.097794
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       7352.000000       7352.000000       7352.000000       7352.000000
# mean          -0.605438         -0.510938         -0.604754         -0.630512
# std            0.448734          0.502645          0.418687          0.424073
# min           -1.000000         -0.999873         -1.000000         -1.000000
# 25%           -0.992754         -0.978129         -0.980233         -0.993591
# 50%           -0.946196         -0.851897         -0.859365         -0.950709
# 75%           -0.242813         -0.034231         -0.262415         -0.292680
# max            1.000000          0.916238          1.000000          1.000000
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# count       7352.000000       7352.000000       7352.000000  ...
# mean          -0.526907         -0.606150         -0.468604  ...
# std            0.485942          0.414122          0.544547  ...
# min           -1.000000         -1.000000         -1.000000  ...
# 25%           -0.978162         -0.980251         -0.936219  ...
# 50%           -0.857328         -0.857143         -0.881637  ...
# 75%           -0.066701         -0.265671         -0.017129  ...
# max            0.967664          1.000000          1.000000  ...
#
#        fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# count                      7352.000000                      7352.000000
# mean                         -0.307009                        -0.625294
# std                           0.321011                         0.307584
# min                          -0.995357                        -0.999765
# 25%                          -0.542602                        -0.845573
# 50%                          -0.343685                        -0.711692
# 75%                          -0.126979                        -0.503878
# max                           0.989538                         0.956845
#
#        angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# count                  7352.000000                           7352.000000
# mean                      0.008684                              0.002186
# std                       0.336787                              0.448306
# min                      -0.976580                             -1.000000
# 25%                      -0.121527                             -0.289549
# 50%                       0.009509                              0.008943
# 75%                       0.150865                              0.292861
# max                       1.000000                              1.000000
#
#        angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# count                       7352.000000                           7352.000000
# mean                           0.008726                             -0.005981
# std                            0.608303                              0.477975
# min                           -1.000000                             -1.000000
# 25%                           -0.482273                             -0.376341
# 50%                            0.008735                             -0.000368
# 75%                            0.506187                              0.359368
# max                            0.998702                              0.996078
#
#        angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# count           7352.000000           7352.000000           7352.000000
# mean              -0.489547              0.058593             -0.056515
# std                0.511807              0.297480              0.279122
# min               -1.000000             -1.000000             -1.000000
# 25%               -0.812065             -0.017885             -0.143414
# 50%               -0.709417              0.182071              0.003181
# 75%               -0.509079              0.248353              0.107659
# max                1.000000              0.478157              1.000000
#
#            subject
# count  7352.000000
# mean     17.413085
# std       8.975143
# min       1.000000
# 25%       8.000000
# 50%      19.000000
# 75%      26.000000
# max      30.000000
#
# [8 rows x 562 columns]

# %%
train_df.shape
# Out:
# (7352, 563)

# %%
train_df.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
X_train = train_df.drop('Activity', axis=1)
y_train = train_df['Activity']

X_test = test_df.drop('Activity', axis=1)
y_test = test_df['Activity']

# %% [markdown]
# ### Model Training and Evaluation

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC

seed = 1
forest = RandomForestClassifier(random_state=seed)
linear = LogisticRegression(max_iter=2000, random_state=seed)
tree = DecisionTreeClassifier(random_state=seed)
svm = LinearSVC(max_iter=2500, random_state=seed)

# %%
models = [forest, linear, tree, svm]
model_names = [
    'Random Forests',
    'Logistic Regression',
    'Decision Tree',
    'Support Vector Machine']

# %%
from sklearn.metrics import accuracy_score

def get_accuracy(model, data):
    X_train, X_test, y_train, y_test = data
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    return acc

# %%
data = (X_train, X_test, y_train, y_test)
for model, model_name in zip(models, model_names):
    acc = get_accuracy(model, data)
    print(model_name)
    print('=========================')
    print('Accuracy: %.2f%%'%(acc*100))
    print()
# Out:
# Random Forests
# =========================
# Accuracy: 92.57%
#
# Logistic Regression
# =========================
# Accuracy: 95.96%
#
# Decision Tree
# =========================
# Accuracy: 86.12%
#
# Support Vector Machine
# =========================
# Accuracy: 96.47%
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,

# %% [markdown]
# ### Using Deep Learning

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.fit_transform(y_test)

# %%
import numpy as np
from tensorflow.keras.utils import to_categorical
X_train, X_test = np.array(X_train), np.array(X_test)
y_train, y_test = to_categorical(y_train_encoded), to_categorical(y_test_encoded)

# %%
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential

model = Sequential()
model.add(BatchNormalization(input_shape=[X_train.shape[1]]))
model.add(Dense(512, activation='relu'))
model.add(Dropout(rate=0.1))
model.add(Dense(512, activation='relu'))
model.add(Dropout(rate=0.1))
model.add(Dense(512, activation='relu'))
model.add(Dense(6, activation='softmax'))
# Out:
# 2022-10-20 12:02:15.730130: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
# compile model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    min_delta=0.001,
    patience=20,
    restore_best_weights=True
)

# %%
history = model.fit(X_train, y_train,
                    validation_data=(X_test, y_test),
                    epochs=500,
                   callbacks=[early_stopping])
# Out:
# 2022-10-20 12:02:15.936193: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/500
# 230/230 [==============================] - 3s 10ms/step - loss: 0.3195 - accuracy: 0.8806 - val_loss: 0.2239 - val_accuracy: 0.9114
# Epoch 2/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.1470 - accuracy: 0.9457 - val_loss: 0.1844 - val_accuracy: 0.9291
# Epoch 3/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.1068 - accuracy: 0.9587 - val_loss: 0.1828 - val_accuracy: 0.9291
# Epoch 4/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.0954 - accuracy: 0.9669 - val_loss: 0.2146 - val_accuracy: 0.9386
# Epoch 5/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.0878 - accuracy: 0.9679 - val_loss: 0.3210 - val_accuracy: 0.9169
# Epoch 6/500
# 230/230 [==============================] - 2s 8ms/step - loss: 0.0851 - accuracy: 0.9695 - val_loss: 0.2057 - val_accuracy: 0.9423
# Epoch 7/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.0793 - accuracy: 0.9732 - val_loss: 0.1707 - val_accuracy: 0.9481
# Epoch 8/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.0808 - accuracy: 0.9718 - val_loss: 0.1567 - val_accuracy: 0.9542
# Epoch 9/500
# 230/230 [==============================] - 3s 11ms/step - loss: 0.0558 - accuracy: 0.9796 - val_loss: 0.1758 - val_accuracy: 0.9505
# Epoch 10/500
# 230/230 [==============================] - 2s 8ms/step - loss: 0.0597 - accuracy: 0.9784 - val_loss: 0.1820 - val_accuracy: 0.9542
# Epoch 11/500
# 230/230 [==============================] - 2s 8ms/step - loss: 0.0391 - accuracy: 0.9864 - val_loss: 0.2193 - val_accuracy: 0.9457
# Epoch 12/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.0460 - accuracy: 0.9849 - val_loss: 0.2363 - val_accuracy: 0.9532
# Epoch 13/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.0475 - accuracy: 0.9834 - val_loss: 0.2320 - val_accuracy: 0.9555
# Epoch 14/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.0552 - accuracy: 0.9834 - val_loss: 0.2309 - val_accuracy: 0.9511
# Epoch 15/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.0334 - accuracy: 0.9884 - val_loss: 0.3445 - val_accuracy: 0.9379
# Epoch 16/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.0329 - accuracy: 0.9879 - val_loss: 0.2032 - val_accuracy: 0.9545
# Epoch 17/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.0401 - accuracy: 0.9874 - val_loss: 0.2273 - val_accuracy: 0.9491
# Epoch 18/500
# 230/230 [==============================] - 2s 10ms/step - loss: 0.0518 - accuracy: 0.9842 - val_loss: 0.1904 - val_accuracy: 0.9559
# Epoch 19/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.0333 - accuracy: 0.9886 - val_loss: 0.2833 - val_accuracy: 0.9491
# Epoch 20/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.0253 - accuracy: 0.9905 - val_loss: 0.2901 - val_accuracy: 0.9444
# Epoch 21/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.0330 - accuracy: 0.9912 - val_loss: 0.4389 - val_accuracy: 0.9437
# Epoch 22/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.0258 - accuracy: 0.9909 - val_loss: 0.4145 - val_accuracy: 0.9440
# Epoch 23/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.0566 - accuracy: 0.9865 - val_loss: 0.3010 - val_accuracy: 0.9491
# Epoch 24/500
# 230/230 [==============================] - 3s 12ms/step - loss: 0.0230 - accuracy: 0.9929 - val_loss: 0.2790 - val_accuracy: 0.9498
# Epoch 25/500
# 230/230 [==============================] - 2s 8ms/step - loss: 0.0321 - accuracy: 0.9890 - val_loss: 0.2864 - val_accuracy: 0.9450
# Epoch 26/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.0305 - accuracy: 0.9925 - val_loss: 0.3638 - val_accuracy: 0.9328
# Epoch 27/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.0284 - accuracy: 0.9936 - val_loss: 0.3398 - val_accuracy: 0.9562
# Epoch 28/500
# 230/230 [==============================] - 2s 9ms/step - loss: 0.0286 - accuracy: 0.9903 - val_loss: 0.3141 - val_accuracy: 0.9406

# %%
history_df = pd.DataFrame(history.history)
# Start the plot at epoch 5
history_df.loc[5:, ['loss', 'val_loss']].plot()
history_df.loc[5:, ['accuracy', 'val_accuracy']].plot()

print(("Best Validation Loss: {:0.4f}" +\
      "\nBest Validation Accuracy: {:0.4f}")\
      .format(history_df['val_loss'].min(), 
              history_df['val_accuracy'].max()))
# Out:
# Best Validation Loss: 0.1567
# Best Validation Accuracy: 0.9562
